# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# First we visualize the given function

# %%
f = lambda x: 4*x[0] + 6*x[1] - 2*x[0]**2 - 2*x[0]*x[1] - 2*x[1]**2

x1 = np.linspace(-10,10,100)
x2 = np.linspace(-10,10,100)

X,Y = np.meshgrid(x1,x2)
F = f((X,Y))

fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection = '3d')

ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('f(X)')

surf = ax.plot_surface(X,Y,F, cmap='jet')

# %%
from scipy.optimize import minimize

# %%
f_ = lambda x: -4*x[0] - 6*x[1] + 2*x[0]**2 + 2*x[0]*x[1] + 2*x[1]**2

# %%
res = minimize(f_, x0=(1,1))
res
# Out:
#   message: Optimization terminated successfully.
#   success: True
#    status: 0
#       fun: -4.666666666666666
#         x: [ 3.333e-01  1.333e+00]
#       nit: 2
#       jac: [ 0.000e+00  0.000e+00]
#  hess_inv: [[ 5.000e-01 -5.000e-01]
#             [-5.000e-01  1.000e+00]]
#      nfev: 15
#      njev: 5

# %%
res.x
# Out:
# array([0.33333333, 1.33333333])

# %%
f = lambda x: 4*x[0] + 6*x[1] - 2*x[0]**2 - 2*x[0]*x[1] - 2*x[1]**2

x1 = np.linspace(-10,10,100)
x2 = np.linspace(-10,10,100)

X,Y = np.meshgrid(x1,x2)
F = f((X,Y))

fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection = '3d')

ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('f(X)')

surf = ax.plot_surface(X,Y,F, cmap='jet')
ax.plot(res.x[0],res.x[1], 'ob', )

# %% [markdown]
# As we can see in the plot, there is a small dot that says z in the graph which is global maxima that we have reached.
